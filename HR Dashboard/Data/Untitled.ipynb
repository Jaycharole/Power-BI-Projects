# %%
import pandas as pd

# %%
data = pd.read_csv('datascience_jobs.csv')

# %%
data
# Out:
#                                               Job Title  \
# 0             ASSOCIATE DATA SCIENTIST / DATA SCIENTIST
# 1                    Data Analyst – Campaign Specialist
# 2                                          Data Analyst
# 3                                          Data Analyst
# 4                                        Data Scientist
# ...                                                 ...
# 3065  Consultant â Data Solution (Entry / Middle L...
# 3066     Analyst Programmer (Java, J2EE, Oracle DB, BI)
# 3067          Programmer / Analyst Programmer (.Net C#)
# 3068  Senior Associate / Associate (Audit Analytics)...
# 3069                                  Senior IT Officer
#
#                                        Company           Area Employer Email  \
# 0              Sun Hung Kai Properties Limited  Not Specified            NaN
# 1                                       now TV  Not Specified            NaN
# ...

# %%
data.to_csv('dsjobs.csv')
